# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
df = pd.read_csv("Diabetes_type2_raw.csv")
print(df.head(10))
# Out:
#                Name  Gender  BP(Systolic)  BP(Diastolic) Physical_Activity  \
# 0     Michael Jones    Male         140.0           90.0               Low
# 1      Sandra Green  Female         110.0           80.0               Low
# 2    Jennifer Lewis  Female         120.0           80.0            Medium
# 3   Ronald Gonzalez    Male         130.0           85.0               Low
# 4   Ashley Mitchell  Female         110.0           75.0               Low
# 5      Andrew Smith    Male         100.0           80.0              High
# 6     Matthew Lewis    Male         110.0           80.0              High
# 7      Melissa Hill  Female          90.0           65.0               Low
# 8   Patricia Walker  Female         110.0           70.0              High
# 9  Joseph Hernandez    Male         140.0           80.0               Low
#
#     Age        BMI  DiabetesPedigreeFunction  Insulin  Skin Thickness(mm)  \
# 0  50.0  22.263762                       0.0     92.3              317.50
# 1  40.0  24.111159                       2.0    178.9              317.50
# 2  21.0  17.183204                       0.0    198.4              259.08
# 3  30.0  21.244332                       NaN     61.2                 NaN
# 4  35.0  22.819490                       0.0     56.4              335.28
# 5  40.0  24.972272                       3.0    194.2              307.34
# 6  55.0  29.289552                       2.0     28.5              330.20
# 7  86.0  24.603224                       0.0    100.2              279.40
# 8   NaN  23.680603                       0.0    190.0              330.20
# 9   NaN  32.722288                       5.0    141.2              375.92
#
#    Glucose
# 0    146.0
# 1      NaN
# 2     97.0
# 3    178.0
# 4    167.0
# 5    179.0
# 6    117.0
# 7     93.0
# 8    122.0
# 9    184.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      241 non-null    object
#  1   Gender                    243 non-null    object
#  2   BP(Systolic)              241 non-null    float64
#  3   BP(Diastolic)             231 non-null    float64
#  4   Physical_Activity         238 non-null    object
#  5   Age                       230 non-null    float64
#  6   BMI                       229 non-null    float64
#  7   DiabetesPedigreeFunction  233 non-null    float64
#  8   Insulin                   250 non-null    float64
#  9   Skin Thickness(mm)        233 non-null    float64
#  10  Glucose                   231 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 18.6+ KB

# %%
df.describe()
# Out:
#        BP(Systolic)  BP(Diastolic)         Age         BMI  \
# count    241.000000     231.000000  230.000000  229.000000
# mean     118.132780      77.077922   43.491304   25.089468
# std       15.077543      14.242099   13.346488    4.053550
# min       90.000000       0.000000   21.000000   17.183204
# 25%      110.000000      70.000000   34.000000   22.177464
# 50%      120.000000      80.000000   40.000000   24.193597
# 75%      120.000000      80.000000   52.000000   28.117970
# max      160.000000     110.000000   86.000000   36.957845
#
#        DiabetesPedigreeFunction     Insulin  Skin Thickness(mm)     Glucose
# count                233.000000  250.000000          233.000000  231.000000
# mean                   1.459227  139.870000          319.940386  151.150649
# std                    1.461964   73.477597           36.145463   67.890827
# min                    0.000000   15.400000           29.210000   50.000000
# 25%                    0.000000   79.425000          304.800000   95.000000
# 50%                    1.000000  132.650000          317.500000  140.000000
# 75%                    2.000000  208.650000          342.900000  200.000000
# max                    8.000000  274.800000          406.400000  370.000000

# %%
print(df.isnull().sum())
# Out:
# Name                         9
# Gender                       7
# BP(Systolic)                 9
# BP(Diastolic)               19
# Physical_Activity           12
# Age                         20
# BMI                         21
# DiabetesPedigreeFunction    17
# Insulin                      0
# Skin Thickness(mm)          17
# Glucose                     19
# dtype: int64

# %%
numerical_columns = [ "BP(Systolic)","BP(Diastolic)","Age", "BMI","DiabetesPedigreeFunction","Skin Thickness(mm)","Insulin","Glucose"]  

df[numerical_columns] = df[numerical_columns].astype(float)
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].median())
print(df)
# Out:
#                 Name  Gender  BP(Systolic)  BP(Diastolic) Physical_Activity  \
# 0      Michael Jones    Male         140.0           90.0               Low
# 1       Sandra Green  Female         110.0           80.0               Low
# 2     Jennifer Lewis  Female         120.0           80.0            Medium
# 3    Ronald Gonzalez    Male         130.0           85.0               Low
# 4    Ashley Mitchell  Female         110.0           75.0               Low
# ..               ...     ...           ...            ...               ...
# 245    Timothy Davis    Male         100.0           70.0            Medium
# 246     Robert Allen    Male         160.0           90.0               Low
# 247      Karen Adams  Female         140.0           80.0            Medium
# 248      Deborah Lee  Female         100.0           70.0              High
# 249  Damon Salvatore    Male         120.0           80.0              High
#
#       Age        BMI  DiabetesPedigreeFunction  Insulin  Skin Thickness(mm)  \
# 0    50.0  22.263762                       0.0     92.3              317.50
# 1    40.0  24.111159                       2.0    178.9              317.50
# 2    21.0  17.183204                       0.0    198.4              259.08
# 3    30.0  21.244332                       1.0     61.2              317.50
# 4    35.0  22.819490                       0.0     56.4              335.28
# ..    ...        ...                       ...      ...                 ...
# 245  60.0  25.341906                       2.0    142.7              228.60
# 246  51.0  28.117970                       1.0    238.1              304.80
# 247  30.0  22.388934                       1.0    274.8              292.10
# 248  40.0  22.493998                       3.0    139.9              266.70
# 249  32.0  25.600000                       0.0    200.0              260.00
#
#      Glucose
# 0      146.0
# 1      140.0
# 2       97.0
# 3      178.0
# 4      167.0
# ..       ...
# 245     90.0
# 246     99.0
# 247    100.0
# 248     63.0
# 249    100.0
#
# [250 rows x 11 columns]

# %%
print(df.isnull().sum())
# Out:
# Name                         9
# Gender                       7
# BP(Systolic)                 0
# BP(Diastolic)                0
# Physical_Activity           12
# Age                          0
# BMI                          0
# DiabetesPedigreeFunction     0
# Insulin                      0
# Skin Thickness(mm)           0
# Glucose                      0
# dtype: int64

# %%
Categorical_columns = ["Gender", "Physical_Activity"]  

df[Categorical_columns] = df[Categorical_columns].fillna(df[Categorical_columns].mode().iloc[0])
print(df.isnull().sum())
# Out:
# Name                        9
# Gender                      0
# BP(Systolic)                0
# BP(Diastolic)               0
# Physical_Activity           0
# Age                         0
# BMI                         0
# DiabetesPedigreeFunction    0
# Insulin                     0
# Skin Thickness(mm)          0
# Glucose                     0
# dtype: int64

# %%
for column in Categorical_columns :
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
print(df.head(10))
# Out:
#                Name  Gender  BP(Systolic)  BP(Diastolic)  Physical_Activity  \
# 0     Michael Jones       1         140.0           90.0                  1
# 1      Sandra Green       0         110.0           80.0                  1
# 2    Jennifer Lewis       0         120.0           80.0                  2
# 3   Ronald Gonzalez       1         130.0           85.0                  1
# 4   Ashley Mitchell       0         110.0           75.0                  1
# 5      Andrew Smith       1         100.0           80.0                  0
# 6     Matthew Lewis       1         110.0           80.0                  0
# 7      Melissa Hill       0          90.0           65.0                  1
# 8   Patricia Walker       0         110.0           70.0                  0
# 9  Joseph Hernandez       1         140.0           80.0                  1
#
#     Age        BMI  DiabetesPedigreeFunction  Insulin  Skin Thickness(mm)  \
# 0  50.0  22.263762                       0.0     92.3              317.50
# 1  40.0  24.111159                       2.0    178.9              317.50
# 2  21.0  17.183204                       0.0    198.4              259.08
# 3  30.0  21.244332                       1.0     61.2              317.50
# 4  35.0  22.819490                       0.0     56.4              335.28
# 5  40.0  24.972272                       3.0    194.2              307.34
# 6  55.0  29.289552                       2.0     28.5              330.20
# 7  86.0  24.603224                       0.0    100.2              279.40
# 8  40.0  23.680603                       0.0    190.0              330.20
# 9  40.0  32.722288                       5.0    141.2              375.92
#
#    Glucose
# 0    146.0
# 1    140.0
# 2     97.0
# 3    178.0
# 4    167.0
# 5    179.0
# 6    117.0
# 7     93.0
# 8    122.0
# 9    184.0

# %%
scaler = StandardScaler()

df[numerical_columns] = scaler.fit_transform(df[numerical_columns])
print(df.head(10))
# Out:
#                Name  Gender  BP(Systolic)  BP(Diastolic)  Physical_Activity  \
# 0     Michael Jones       1      1.475265       0.928195                  1
# 1      Sandra Green       0     -0.554916       0.197333                  1
# 2    Jennifer Lewis       0      0.121811       0.197333                  2
# 3   Ronald Gonzalez       1      0.798538       0.562764                  1
# 4   Ashley Mitchell       0     -0.554916      -0.168098                  1
# 5      Andrew Smith       1     -1.231643       0.197333                  0
# 6     Matthew Lewis       1     -0.554916       0.197333                  0
# 7      Melissa Hill       0     -1.908370      -0.898960                  1
# 8   Patricia Walker       0     -0.554916      -0.533529                  0
# 9  Joseph Hernandez       1      1.475265       0.197333                  1
#
#         Age       BMI  DiabetesPedigreeFunction   Insulin  Skin Thickness(mm)  \
# 0  0.529952 -0.709052                 -1.010553 -0.648707           -0.065310
# 1 -0.250767 -0.232803                  0.404787  0.532248           -0.065310
# 2 -1.734132 -2.018793                 -1.010553  0.798167           -1.742824
# 3 -1.031486 -0.971856                 -0.302883 -1.072814           -0.065310
# 4 -0.641126 -0.565788                 -1.010553 -1.138271            0.445238
# 5 -0.250767 -0.010813                  1.112458  0.740892           -0.357051
# 6  0.920311  1.102159                  0.404787 -1.518741            0.299367
# 7  3.340539 -0.105951                 -1.010553 -0.540975           -1.159341
# 8 -0.250767 -0.343798                 -1.010553  0.683617            0.299367
# 9 -0.250767  1.987101                  2.527798  0.018137            1.612204
#
#     Glucose
# 0 -0.066015
# 1 -0.158059
# 2 -0.817714
# 3  0.424891
# 4  0.256142
# 5  0.440232
# 6 -0.510898
# 7 -0.879078
# 8 -0.434194
# 9  0.516936
